# %% [markdown]
# <a href="https://colab.research.google.com/github/sc2377/python_programming/blob/main/Exercise_12_(LoadDate(Pandas))_%EC%9D%B4%EC%84%B1%EC%B2%A0_2022189117_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 파이썬 프로그래밍
# 이성철 2022189117

# Exercise 8 (Function)
# 류호경 교수님 파트

# 구글 드라이브에 있는 Pandas를 쓴다
# 내 구글 드라이브에 07.TopSellingAlbums.csv, 07.TopSellingAlbums.xlsx 업로드

import pandas as pd #pandas library import

# %%
# intialise data of lists.
data = {'Name':['Tom', 'nick', 'krish', 'jack'],
        'Age':[20, 21, 19, 18]}
 
# Create DataFrame
df = pd.DataFrame(data)
 
# Print the output.
print(df)
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
csv_path = '/content/gdrive/My Drive/Colab Notebooks/07.TopSellingAlbums.csv' # 파일명 앞에 07 붙임
df = pd.read_csv(csv_path)

# %%
# Print first five rows of the dataframe
#df.head()

# Print last five rows of the dataframe
df.tail()
# Out:
#             Artist                            Album  Released   Length  \
# 3  Whitney Houston                    The Bodyguard      1992  0:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# 6         Bee Gees             Saturday Night Fever      1977  1:15:54
# 7    Fleetwood Mac                          Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
# 5   rock, soft rock, folk rock                              32.2
# 6                        disco                              20.6
# 7                    soft rock                              27.9
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 3                        44  17-Nov-92          Y     8.5
# ...

# %%
xlsx_path = '/content/gdrive/My Drive/Colab Notebooks/07.TopSellingAlbums.xlsx' # 파일명 앞에 07 붙임

df1 = pd.read_excel(xlsx_path)
df1.head()
# Out:
#             Artist                      Album  Released    Length  \
# 0  Michael Jackson                   Thriller      1982  00:42:19
# 1            AC/DC              Back in Black      1980  00:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  00:42:49
# 3  Whitney Houston              The Bodyguard      1992  00:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  00:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65 1982-11-30        NaN    10.0
# 1                        50 1980-07-25        NaN     9.5
# ...

# %%
x = df[['Genre']]
x
# Out:
#                          Genre
# 0               pop, rock, R&B
# 1                    hard rock
# 2             progressive rock
# 3               R&B, soul, pop
# 4  hard rock, progressive rock
# 5   rock, soft rock, folk rock
# 6                        disco
# 7                    soft rock

# %%
x = df['Length']
x
# Out:
# 0    0:42:19
# 1    0:42:11
# 2    0:42:49
# 3    0:57:44
# 4    0:46:33
# 5    0:43:08
# 6    1:15:54
# 7    0:40:01
# Name: Length, dtype: object

# %%
x = df[['Artist']]
x
# Out:
#             Artist
# 0  Michael Jackson
# 1            AC/DC
# 2       Pink Floyd
# 3  Whitney Houston
# 4        Meat Loaf
# 5           Eagles
# 6         Bee Gees
# 7    Fleetwood Mac

# %%
y = df[['Artist','Length','Genre']]
y
# Out:
#             Artist   Length                        Genre
# 0  Michael Jackson  0:42:19               pop, rock, R&B
# 1            AC/DC  0:42:11                    hard rock
# 2       Pink Floyd  0:42:49             progressive rock
# 3  Whitney Houston  0:57:44               R&B, soul, pop
# 4        Meat Loaf  0:46:33  hard rock, progressive rock
# 5           Eagles  0:43:08   rock, soft rock, folk rock
# 6         Bee Gees  1:15:54                        disco
# 7    Fleetwood Mac  0:40:01                    soft rock

# %%
df.iloc[0, 0] #첫번째 행, 첫번째 열
# Out:
# 'Michael Jackson'

# %%
df.iloc[1,0] #두번째 행, 첫번째 열
# Out:
# 'AC/DC'

# %%
df.iloc[0,2]
# Out:
# 1982

# %%
df.loc[0, 'Artist']
# Out:
# 'Michael Jackson'

# %%
df.loc[1, 'Artist']
# Out:
# 'AC/DC'

# %%
df.loc[0, 'Released']
# Out:
# 1982

# %%
df.loc[1, 'Released']
# Out:
# 1980

# %%
df.iloc[0:2, 0:3]
# Out:
#             Artist          Album  Released
# 0  Michael Jackson       Thriller      1982
# 1            AC/DC  Back in Black      1980

# %%
df.iloc[0:2, 0:3] #row, column sequence
# Out:
#             Artist          Album  Released
# 0  Michael Jackson       Thriller      1982
# 1            AC/DC  Back in Black      1980

# %%
df.loc[0:2, 'Artist':'Released']
# Out:
#             Artist                      Album  Released
# 0  Michael Jackson                   Thriller      1982
# 1            AC/DC              Back in Black      1980
# 2       Pink Floyd  The Dark Side of the Moon      1973

# %%
for i, j in df.iterrows():
    print(i, j)
    print()
# Out:
# 0 Artist                              Michael Jackson
# Album                                      Thriller
# Released                                       1982
# Length                                      0:42:19
# Genre                                pop, rock, R&B
# Music Recording Sales (millions)               46.0
# Claimed Sales (millions)                         65
# Released.1                                30-Nov-82
# Soundtrack                                      NaN
# Rating                                         10.0
# Name: 0, dtype: object
#
# 1 Artist                                      AC/DC
# Album                               Back in Black
# Released                                     1980
# Length                                    0:42:11
# Genre                                   hard rock
# Music Recording Sales (millions)             26.1
# Claimed Sales (millions)                       50
# Released.1                              25-Jul-80
# ...

# %%
filter2 = df["Claimed Sales (millions)"]>40
  
# filtering data on basis of both filters 
df.where(filter2)
# Out:
#             Artist                            Album  Released   Length  \
# 0  Michael Jackson                         Thriller    1982.0  0:42:19
# 1            AC/DC                    Back in Black    1980.0  0:42:11
# 2       Pink Floyd        The Dark Side of the Moon    1973.0  0:42:49
# 3  Whitney Houston                    The Bodyguard    1992.0  0:57:44
# 4        Meat Loaf                  Bat Out of Hell    1977.0  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)    1976.0  0:43:08
# 6              NaN                              NaN       NaN      NaN
# 7              NaN                              NaN       NaN      NaN
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# ...

# %%
# Quiz

q = df[['Rating']]
q
# Out:
#    Rating
# 0    10.0
# 1     9.5
# 2     9.0
# 3     8.5
# 4     8.0
# 5     7.5
# 6     7.0
# 7     6.5

# %%
q = df[['Released', 'Artist']]
q
# Out:
#    Released           Artist
# 0      1982  Michael Jackson
# 1      1980            AC/DC
# 2      1973       Pink Floyd
# 3      1992  Whitney Houston
# 4      1977        Meat Loaf
# 5      1976           Eagles
# 6      1977         Bee Gees
# 7      1977    Fleetwood Mac

# %%
q = df[['Released', 'Artist']]
q
# Out:
#    Released           Artist
# 0      1982  Michael Jackson
# 1      1980            AC/DC
# 2      1973       Pink Floyd
# 3      1992  Whitney Houston
# 4      1977        Meat Loaf
# 5      1976           Eagles
# 6      1977         Bee Gees
# 7      1977    Fleetwood Mac

# %%
df.iloc[1, 2]
# Out:
# 1980
